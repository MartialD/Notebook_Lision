# %% [markdown]
# ## Hyperspy notebook to analyze spectroscopic data using VCA algorithm

# %% [markdown]
# #### by Martial Duchamp
# NTU-MSE, Singapore m.duchamp@ntu.edu.sg

# %% [markdown]
# ### Absract:
# The notebook demonstrates usage of the VCA to denoising spectroscopic data

# %% [markdown]
# ### Preamble:

# %%
import hyperspy.api as hs
# Out:
# WARNING:hyperspy_gui_traitsui:The module://ipykernel.pylab.backend_inline matplotlib backend is not compatible with the traitsui GUI elements. For more information, read http://hyperspy.readthedocs.io/en/stable/user_guide/getting_started.html#possible-warnings-when-importing-hyperspy.
# WARNING:hyperspy_gui_traitsui:The traitsui GUI elements are not available.

# %% [markdown]
# import sys
# sys.path.insert(0, '/home/martial/Data/programs/Github/hyperspy_T')
#
# import hyperspy.api as hs

# %%
hs.hyperspy.Release.info
# Out:
# '\n    H y p e r S p y\n    Version 1.5.2\n\n    http://www.hyperspy.org\n\n    '

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib qt5

# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
### For EELS spectra
path = "/home/martial/OneDrive/Data_NTU/Fred/2021-02-04/Ti3C2-pyr/SI data (1)/"
eels_raw = hs.load(path+"EELS Spectrum Image.dm4") #3D data

# %%
eels_live_img = hs.load(path+"ATT1 Image.dm4")

# %%
eels_raw.plot(navigator=eels_live_img)

# %% [markdown]
# eels_raw.data[eels_raw.data[:]<0]=0

# %%
eels_raw

# %%
eels_raw.align_zero_loss_peak(subpixel="True", show_progressbar="True", crop="False")
# Out:
# Initial ZLP position statistics
# -------------------------------
# Summary statistics
# ------------------
# mean:	-6.8
# std:	0.247
#
# min:	-7.3
# Q1:	-7
# median:	-6.8
# Q3:	-6.6
# max:	-6.1
# ...

# %%
eels_raw.plot(navigator=eels_live_img)

# %%
eels_raw.crop_signal1D(30.,45.)

# %%
eels_raw.plot(navigator=eels_live_img)

# %%
eels_raw.decomposition(algorithm='nmf')

# %%
eels_raw.plot_decomposition_factors(3)

# %%
eels_raw.plot_decomposition_loadings(3)

# %%
eels_raw.plot_explained_variance_ratio()
